# %% [markdown]
# # Laboratorio 2.1

# %% [markdown]
# **Ejercicio 1:** Contruir un función que dado un iterable, devuelva un diccionario con las frecuencias de sus elementos

# %%
def frecuencias(iterable):

    diccionario = {}

    for i in iterable:
        if i in diccionario:
            diccionario[i] += 1
        else:
            diccionario[i] = 1
    return diccionario

# %% [markdown]
# Prueba:

# %%
print("Ejercicio 1: {0}".format(frecuencias([1,5,4,2,1,5,4,7,8,9,8,1])))
# Out:
# Ejercicio 1: {1: 3, 5: 2, 4: 2, 2: 1, 7: 1, 8: 2, 9: 1}

# %% [markdown]
# **Ejercicio 2:** Construir una funcion que se llame **suma_acotados**. Esta función debe tomar un número arbitrario de argumentos posicionales y un keyword argument llamado **cota**, que por defecto debe tener un valor **None**. Si el argumento **cota** es **None**, debe sumar todos los números, si no debe sumar los números que se encuenren entre **-cota** y **cota**.

# %%
def suma_acotados(*args, cota=None):
    if cota == None:
        suma = 0
        for num in args:
            suma += num
    else:
        suma = 0
        for num in args:
            if -cota <= num <= cota:
                suma += num         
    return suma

# %% [markdown]
# Pureba:

# %%
print("Ejercicio 2: {0}".format(suma_acotados(6, 2, 3, 8, 9, 7, 5, 1, 3, 2, 5, 4, 8 , cota=5)))
# Out:
# Ejercicio 2: 25

# %%
print("Ejercicio 2: {0}".format(suma_acotados(6, 2, 3, 8, 9, 7, 5, 1, 3, 2, 5, 4, 8)))
# Out:
# Ejercicio 2: 63
